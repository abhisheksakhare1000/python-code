# %%
import logging

# %%
logging.basicConfig(filename = "test.log", level = logging.INFO)

# %%
logging.info("This is my info log")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 440, in format
#     return self._format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 436, in _format
#     return self._fmt % values
# ValueError: unsupported format character '%' (0x25) at index 25
# Call stack:
#   File "/opt/conda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
# ...

# %%
logging.info("this is my info log")
logging.warning("this is my warning  log")
logging.error("this is my error log")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 440, in format
#     return self._format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 436, in _format
#     return self._fmt % values
# ValueError: unsupported format character '%' (0x25) at index 25
# Call stack:
#   File "/opt/conda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
# ...

# %%
logging.shutdown()

# %%
logging.basicConfig( filename = "tesee.log" , level = logging.DEBUG, format = '%(asctime)s %(levelname)s %(message)s') # it gives date and time

# %%
logging.info("this is  my info log") #
logging.warning("this is my waring log")
logging.debug("this is my debug log")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 440, in format
#     return self._format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 436, in _format
#     return self._fmt % values
# ValueError: unsupported format character '%' (0x25) at index 25
# Call stack:
#   File "/opt/conda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
# ...

# %%
import logging

# %%
logging.basicConfig( filename = "test2.log" , level = logging.DEBUG, format = '%(asctime)s %(levelname)s %(message)s') # it gives date and time

# %%
# priorty
#1 error
#2 waring
#3 info
#4 debug
#in level = logging.DEBUG in this code we are prioriting debug as priority

# %%
def divbyzero(a,b):
    logging.info("this is start of my code %s and %s", a,b)
    try:
        div = a/b
        logging.info("execute succ")
    except Exception as e:
        logging.error("error has happened")
        logging.exception("Exception occured", str(e))

# %%
 divbyzero(4,5)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 440, in format
#     return self._format(record)
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 436, in _format
#     return self._fmt % values
# ValueError: unsupported format character '%' (0x25) at index 25
# Call stack:
#   File "/opt/conda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
# ...
