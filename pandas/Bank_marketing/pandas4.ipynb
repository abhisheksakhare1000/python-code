# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.describe() # its given info of numeric data not of object data type
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
col_name = df.dtypes[df.dtypes=="object"].index  # This retrieves the index (i.e., the column names)

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# to add new column
df["inueron"] = "abhi"
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked inueron
# 0        0         A/5 21171   7.2500   NaN        S    abhi
# 1        0          PC 17599  71.2833   C85        C    abhi
# 2        0  STON/O2. 3101282   7.9250   NaN        S    abhi
# 3        0            113803  53.1000  C123        S    abhi
# 4        0            373450   8.0500   NaN        S    abhi
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    abhi
# 887      0            112053  30.0000   B42        S    abhi
# 888      2        W./C. 6607  23.4500   NaN        S    abhi
# 889      0            111369  30.0000  C148        C    abhi
# 890      0            370376   7.7500   NaN        Q    abhi
#
# [891 rows x 13 columns]

# %%
df['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
 df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked inueron
# 0        0         A/5 21171   7.2500   NaN        S    abhi
# 1        0          PC 17599  71.2833   C85        C    abhi
# 2        0  STON/O2. 3101282   7.9250   NaN        S    abhi
# 3        0            113803  53.1000  C123        S    abhi
# 4        0            373450   8.0500   NaN        S    abhi
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    abhi
# 887      0            112053  30.0000   B42        S    abhi
# 888      2        W./C. 6607  23.4500   NaN        S    abhi
# 889      0            111369  30.0000  C148        C    abhi
# 890      0            370376   7.7500   NaN        Q    abhi
#
# [891 rows x 13 columns]

# %%
df['Age'].isnull()== True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull()== True] # give value which age has null
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked inueron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    abhi
# 17     male  NaN      0      0      244373  13.0000   NaN        S    abhi
# 19   female  NaN      0      0        2649   7.2250   NaN        C    abhi
# 26     male  NaN      0      0        2631   7.2250   NaN        C    abhi
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    abhi
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    abhi
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    abhi
# 868    male  NaN      0      0      345777   9.5000   NaN        S    abhi
# 878    male  NaN      0      0      349217   7.8958   NaN        S    abhi
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    abhi
#
# [177 rows x 13 columns]

# %%
ind = df[df['Age'].isnull()== True].index

# %%
len(df[df['Age'].isnull()== True].index)
# Out:
# 177

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked inueron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    abhi
# 17     male  NaN      0      0      244373  13.0000   NaN        S    abhi
# 19   female  NaN      0      0        2649   7.2250   NaN        C    abhi
# 26     male  NaN      0      0        2631   7.2250   NaN        C    abhi
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    abhi
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    abhi
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    abhi
# 868    male  NaN      0      0      345777   9.5000   NaN        S    abhi
# 878    male  NaN      0      0      349217   7.8958   NaN        S    abhi
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    abhi
#
# [177 rows x 13 columns]

# %%
df[df["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked inueron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    abhi
# 17     male  NaN      0      0      244373  13.0000   NaN        S    abhi
# 19   female  NaN      0      0        2649   7.2250   NaN        C    abhi
# 26     male  NaN      0      0        2631   7.2250   NaN        C    abhi
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    abhi
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    abhi
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    abhi
# 868    male  NaN      0      0      345777   9.5000   NaN        S    abhi
# 878    male  NaN      0      0      349217   7.8958   NaN        S    abhi
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    abhi
#
# [177 rows x 13 columns]

# %%
# for getting highest fare
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare'] == max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# 1 . Find out how many male and female passenger was onboarded .
df[df['Sex']=="male"].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   577.000000  577.000000  577.000000  453.000000  577.000000
# mean    454.147314    0.188908    2.389948   30.726645    0.429809
# std     257.486139    0.391775    0.813580   14.678201    1.061811
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.000000    0.000000    2.000000   21.000000    0.000000
# 50%     464.000000    0.000000    3.000000   29.000000    0.000000
# 75%     680.000000    0.000000    3.000000   39.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  577.000000  577.000000
# mean     0.235702   25.523893
# std      0.612294   43.138263
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   10.500000
# 75%      0.000000   26.550000
# max      5.000000  512.329200

# %%
# 1 . Find out how many male and female passenger was onboarded .
male_count = df[df['Sex']=="female"].shape[0]  # shape[0] : reprents row , shape[1] : represents columns
male_count
# Out:
# 314

# %%
female_count = df[df["Sex"] == "male"].shape[0]
female_count
# Out:
# 577

# %%
# how many users do we have with housing and personal loan 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked inueron
# 0        0         A/5 21171   7.2500   NaN        S    abhi
# 1        0          PC 17599  71.2833   C85        C    abhi
# 2        0  STON/O2. 3101282   7.9250   NaN        S    abhi
# 3        0            113803  53.1000  C123        S    abhi
# 4        0            373450   8.0500   NaN        S    abhi
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    abhi
# 887      0            112053  30.0000   B42        S    abhi
# 888      2        W./C. 6607  23.4500   NaN        S    abhi
# 889      0            111369  30.0000  C148        C    abhi
# 890      0            370376   7.7500   NaN        Q    abhi
#
# [891 rows x 13 columns]

# %%
#  3. how many person do we have whose age is 60+ .

# %%
df[df['Age']>60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 545          546         0       1               Nicholson, Mr. Arthur Ernest
# 555          556         0       1                         Wright, Mr. George
# 570          571         1       2                         Harris, Mr. George
# 625          626         0       1                      Sutton, Mr. Frederick
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 851          852         0       3                        Svensson, Mr. Johan
#
#         Sex   Age  SibSp  Parch       Ticket      Fare        Cabin Embarked  \
# 33     male  66.0      0      0   C.A. 24579   10.5000          NaN        S
# 54     male  65.0      0      1       113509   61.9792          B30        C
# 96     male  71.0      0      0     PC 17754   34.6542           A5        C
# 116    male  70.5      0      0       370369    7.7500          NaN        Q
# 170    male  61.0      0      0       111240   33.5000          B19        S
# 252    male  62.0      0      0       113514   26.5500          C87        S
# 275  female  63.0      1      0        13502   77.9583           D7        S
# 280    male  65.0      0      0       336439    7.7500          NaN        Q
# 326    male  61.0      0      0       345364    6.2375          NaN        S
# 438    male  64.0      1      4        19950  263.0000  C23 C25 C27        S
# 456    male  65.0      0      0        13509   26.5500          E38        S
# 483  female  63.0      0      0         4134    9.5875          NaN        S
# 493    male  71.0      0      0     PC 17609   49.5042          NaN        C
# 545    male  64.0      0      0          693   26.0000          NaN        S
# 555    male  62.0      0      0       113807   26.5500          NaN        S
# 570    male  62.0      0      0  S.W./PP 752   10.5000          NaN        S
# 625    male  61.0      0      0        36963   32.3208          D50        S
# 630    male  80.0      0      0        27042   30.0000          A23        S
# 672    male  70.0      0      0   C.A. 24580   10.5000          NaN        S
# 745    male  70.0      1      1    WE/P 5735   71.0000          B22        S
# 829  female  62.0      0      0       113572   80.0000          B28      NaN
# 851    male  74.0      0      0       347060    7.7750          NaN        S
#
#     inueron
# 33     abhi
# 54     abhi
# 96     abhi
# 116    abhi
# 170    abhi
# 252    abhi
# 275    abhi
# 280    abhi
# 326    abhi
# 438    abhi
# 456    abhi
# 483    abhi
# 493    abhi
# 545    abhi
# 555    abhi
# 570    abhi
# 625    abhi
# 630    abhi
# 672    abhi
# 745    abhi
# 829    abhi
# 851    abhi

# %%
#dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

df = pd.read_csv('bank.csv' , sep=";")

# %%
# 1 . how many campaign available in this dataset . 
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
unique_campaigns = df['campaign'].unique()
unique_campaigns
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
unique_campaigns.shape[0]
# Out:
# 32

# %%
# 2 . how many users do we have with housing and personal loan . 

df[df['loan']=='yes'].shape[0]
#4521 people have loan
# Out:
# 4521

# %%
# 3. how many person do we have whose age is 60+ . 
df[df['age']>60].shape[0]
# Out:
# 127

# %%
# 4 . in which month we have trageted most of the customer . 
max(df['month'])
# Out:
# 'sep'

# %%
# 5 . which mode of call is giving you more result
max(df['contact'][df['y']=='yes'])
# Out:
# 'unknown'

# %%
# 6 . how many enterpeures do we have in this list  
df[df['job']=='entrepreneur']
# Out:
#       age           job   marital  education default  balance housing loan  \
# 8      41  entrepreneur   married   tertiary      no      221     yes  yes
# 23     44  entrepreneur   married  secondary      no       93      no  yes
# 48     32  entrepreneur    single    primary     yes     -849     yes  yes
# 71     42  entrepreneur  divorced   tertiary     yes        2     yes  yes
# 150    41  entrepreneur   married    unknown      no       89     yes  yes
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 4401   38  entrepreneur  divorced   tertiary      no     7929      no  yes
# 4402   41  entrepreneur   married    primary      no       39     yes  yes
# 4487   49  entrepreneur  divorced  secondary      no       32      no  yes
# 4497   31  entrepreneur    single   tertiary      no       38      no  yes
# 4520   44  entrepreneur    single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 8      unknown   14   may        57         2     -1         0  unknown   no
# 23    cellular    7   jul       125         2     -1         0  unknown   no
# 48    cellular    4   feb       204         1     -1         0  unknown   no
# 71     unknown    5   may       380         1     -1         0  unknown   no
# 150    unknown    6   may       333         2     -1         0  unknown   no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4401  cellular    8   jul       182         3     -1         0  unknown   no
# 4402  cellular   21   nov       549         2     -1         0  unknown  yes
# 4487  cellular    5   feb       128         1     -1         0  unknown   no
# 4497  cellular   20   nov       185         2     -1         0  unknown   no
# 4520  cellular    3   apr       345         2    249         7    other   no
#
# [168 rows x 17 columns]

# %%
#  7 . how many customers do we have with negative balance 
df[df['pdays']<0]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no  yes
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes  yes
# 7      39     technician  married  secondary      no      147     yes  yes
# 8      41   entrepreneur  married   tertiary      no      221     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4513   49    blue-collar  married  secondary      no      322      no  yes
# 4515   32       services   single  secondary      no      473     yes  yes
# 4516   33       services  married  secondary      no     -333     yes  yes
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# 7     cellular    6   may       151         2     -1         0  unknown  no
# 8      unknown   14   may        57         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4513  cellular   14   aug       356         2     -1         0  unknown  no
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
#
# [3705 rows x 17 columns]

# %%
#  8. prepare a group of data based on education level . 
df['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
df[df['education']== 'primary']
# Out:
#       age            job  marital education default  balance housing loan  \
# 0      30     unemployed  married   primary      no     1787      no  yes
# 1      33       services  married   primary      no     4789     yes  yes
# 2      35     management   single   primary      no     1350     yes  yes
# 3      30     management  married   primary      no     1476     yes  yes
# 4      59    blue-collar  married   primary      no        0     yes  yes
# ...   ...            ...      ...       ...     ...      ...     ...  ...
# 4516   33       services  married   primary      no     -333     yes  yes
# 4517   57  self-employed  married   primary     yes    -3313     yes  yes
# 4518   57     technician  married   primary      no      295      no  yes
# 4519   28    blue-collar  married   primary      no     1137      no  yes
# 4520   44   entrepreneur   single   primary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
df[df['education']== 'primary']
# Out:
#       age            job  marital education default  balance housing loan  \
# 0      30     unemployed  married   primary      no     1787      no  yes
# 1      33       services  married   primary      no     4789     yes  yes
# 2      35     management   single   primary      no     1350     yes  yes
# 3      30     management  married   primary      no     1476     yes  yes
# 4      59    blue-collar  married   primary      no        0     yes  yes
# ...   ...            ...      ...       ...     ...      ...     ...  ...
# 4516   33       services  married   primary      no     -333     yes  yes
# 4517   57  self-employed  married   primary     yes    -3313     yes  yes
# 4518   57     technician  married   primary      no      295      no  yes
# 4519   28    blue-collar  married   primary      no     1137      no  yes
# 4520   44   entrepreneur   single   primary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]
