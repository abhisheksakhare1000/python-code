# %%
import pandas as pd

# %%
df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1 = df[0]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age' , 'GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv', index = False) # index = false indexes will be removed

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 1

# %%
# if there are multiple table on web-page 
#l[0].to_csv('cricket.csv' , index = False )

# %%
j= l[0]

# %%
j.to_csv('circket.csv', index = False)

# %%
# IF data is json format

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result['name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 result['name']
#
# NameError: name 'result' is not defined

# %%
pd.DataFrame(result['tech'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 pd.DataFrame(result['tech'])
#
# NameError: name 'result' is not defined

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1 = d["data"]

# %%
pd.DataFrame(d1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 pd.DataFrame(d1)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/55244  1908834721
# 1     https://github.com/pandas-dev/pandas/pull/55243  1908832035
# 2     https://github.com/pandas-dev/pandas/pull/55241  1908762323
# 3     https://github.com/pandas-dev/pandas/pull/55240  1908707488
# 4   https://github.com/pandas-dev/pandas/issues/55239  1908544863
# 5   https://github.com/pandas-dev/pandas/issues/55238  1908486520
# 6   https://github.com/pandas-dev/pandas/issues/55237  1908486300
# 7     https://github.com/pandas-dev/pandas/pull/55236  1908063353
# 8     https://github.com/pandas-dev/pandas/pull/55235  1908018573
# 9     https://github.com/pandas-dev/pandas/pull/55234  1907999408
# 10  https://github.com/pandas-dev/pandas/issues/55232  1907678016
# 11  https://github.com/pandas-dev/pandas/issues/55231  1907392574
# 12  https://github.com/pandas-dev/pandas/issues/55230  1907219997
# 13  https://github.com/pandas-dev/pandas/issues/55229  1906858640
# 14  https://github.com/pandas-dev/pandas/issues/55228  1906821298
# 15    https://github.com/pandas-dev/pandas/pull/55227  1906746956
# 16  https://github.com/pandas-dev/pandas/issues/55226  1906564156
# 17  https://github.com/pandas-dev/pandas/issues/55225  1906285254
# 18  https://github.com/pandas-dev/pandas/issues/55224  1906267379
# 19  https://github.com/pandas-dev/pandas/issues/55223  1905530743
# 20  https://github.com/pandas-dev/pandas/issues/55214  1904148036
# 21    https://github.com/pandas-dev/pandas/pull/55213  1904094381
# 22  https://github.com/pandas-dev/pandas/issues/55212  1904026341
# 23  https://github.com/pandas-dev/pandas/issues/55204  1903417694
# 24  https://github.com/pandas-dev/pandas/issues/55202  1903191625
# 25  https://github.com/pandas-dev/pandas/issues/55200  1903100230
# 26  https://github.com/pandas-dev/pandas/issues/55197  1902653988
# 27  https://github.com/pandas-dev/pandas/issues/55196  1902533291
# 28  https://github.com/pandas-dev/pandas/issues/55194  1902350703
# 29  https://github.com/pandas-dev/pandas/issues/55187  1901561244
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85xxoGh   55244
# 1   PR_kwDOAA0YD85a_NAP   55243
# 2   PR_kwDOAA0YD85a-9xJ   55241
# 3   PR_kwDOAA0YD85a-xwP   55240
# 4    I_kwDOAA0YD85xwhVf   55239
# 5    I_kwDOAA0YD85xwTF4   55238
# 6    I_kwDOAA0YD85xwTCc   55237
# 7   PR_kwDOAA0YD85a8mqg   55236
# 8   PR_kwDOAA0YD85a8eBb   55235
# 9   PR_kwDOAA0YD85a8aAA   55234
# 10   I_kwDOAA0YD85xtNtA   55232
# 11   I_kwDOAA0YD85xsIA-   55231
# 12   I_kwDOAA0YD85xrd4d   55230
# 13   I_kwDOAA0YD85xqFqQ   55229
# 14   I_kwDOAA0YD85xp8iy   55228
# 15  PR_kwDOAA0YD85a4JaZ   55227
# 16   I_kwDOAA0YD85xo9w8   55226
# 17   I_kwDOAA0YD85xn5rG   55225
# 18   I_kwDOAA0YD85xn1Tz   55224
# 19   I_kwDOAA0YD85xlBd3   55223
# 20   I_kwDOAA0YD85xfv5E   55214
# 21  PR_kwDOAA0YD85avJ5o   55213
# 22   I_kwDOAA0YD85xfSLl   55212
# 23   I_kwDOAA0YD85xc9le   55204
# 24   I_kwDOAA0YD85xcGZJ   55202
# 25   I_kwDOAA0YD85xbwFG   55200
# 26   I_kwDOAA0YD85xaDIk   55197
# 27   I_kwDOAA0YD85xZlqr   55196
# 28   I_kwDOAA0YD85xY5Fv   55194
# 29   I_kwDOAA0YD85xV4Wc   55187
#
#                                                 title  ... closed_at  \
# 0   BUG: AGAIN!!! pd.to_datetime with dayfirst=Tru...  ...       NaT
# 1   BUG: Rolling pd.date_range incorrect for unit=...  ...       NaT
# 2            PERF: Add type-hints in tzconversion.pyx  ...       NaT
# 3   DOC: point out that explicitly passing axis=No...  ...       NaT
# 4                                 DOC: pd to_datetime  ...       NaT
# 5   BUG: Union of timezone-aware indices with diff...  ...       NaT
# 6   ENH: Bring back the observed argument for grou...  ...       NaT
# 7                  DOC: Fix doc for first_valid_index  ...       NaT
# 8   DEPR: Change FutureWarning for observed=False ...  ...       NaT
# 9   BUG/ENH: Use pyarrow grouped aggregation funct...  ...       NaT
# 10  BUG: `read_csv()` silently ignores out-of-rang...  ...       NaT
# 11  ENH: Export (a subset of?) pandas._typing for ...  ...       NaT
# 12  BUG: pandas, s3fs, and pyarrow  raises OSError...  ...       NaT
# 13                                         RLS: 2.1.2  ...       NaT
# 14  BUG: Get deprecation warning from `Series` con...  ...       NaT
# 15  BUG: Interchange object data buffer has the wr...  ...       NaT
# 16  ENH: Support for list of formats in pd.to_date...  ...       NaT
# 17  ENH: Series.reset_index() should support "name...  ...       NaT
# 18  BUG: Series.value_counts with sort=False retur...  ...       NaT
# 19  BUG: `read_excel` with both `usecols` and `dty...  ...       NaT
# 20  BUILD: pandas build failing on Gitpod due to M...  ...       NaT
# 21  BUG: support non-nanos Timedelta objects in Py...  ...       NaT
# 22  BUG: `df1.merge(df2, on='ds', how='outer')` no...  ...       NaT
# 23  ENH: `rsuffix` parameter of `pandas.DataFrame....  ...       NaT
# 24  PERF: `.iloc[:, :len(columns)+1]` in case of m...  ...       NaT
# 25  BUG: Comment in ODS-file gets included in stri...  ...       NaT
# 26  ENH: Auto-detect text encoding to avoid Unicod...  ...       NaT
# 27  BUG: ExcelWriter set_column with num_format da...  ...       NaT
# 28  BUG: `DataFrame.var()` with `axis=1` returns `...  ...       NaT
# 29                                              DOC:   ...       NaT
#
#    author_association active_lock_reason  \
# 0                NONE                NaN
# 1                NONE                NaN
# 2              MEMBER                NaN
# 3         CONTRIBUTOR                NaN
# 4         CONTRIBUTOR                NaN
# 5         CONTRIBUTOR                NaN
# 6                NONE                NaN
# 7         CONTRIBUTOR                NaN
# 8              MEMBER                NaN
# 9              MEMBER                NaN
# 10        CONTRIBUTOR                NaN
# 11        CONTRIBUTOR                NaN
# 12               NONE                NaN
# 13             MEMBER                NaN
# 14               NONE                NaN
# 15             MEMBER                NaN
# 16               NONE                NaN
# 17             MEMBER                NaN
# 18               NONE                NaN
# 19               NONE                NaN
# 20        CONTRIBUTOR                NaN
# 21               NONE                NaN
# 22               NONE                NaN
# 23               NONE                NaN
# 24               NONE                NaN
# 25               NONE                NaN
# 26               NONE                NaN
# 27               NONE                NaN
# 28               NONE                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   ### Pandas version checks\r\n\r\n- [X] I have ...
# 1   - [X] closes #55026\r\n- [X] [Tests added and ...
# 2   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 3   - [x] closes #54547\r\n\r\npointed out in the ...
# 4   ### Pandas version checks\n\n- [X] I have chec...
# 5   ### Pandas version checks\r\n\r\n- [X] I have ...
# 6   ### Feature Type\n\n- [ ] Adding new functiona...
# 7   - [x] closes #55187\r\n- [x] [Tests added and ...
# 8   - [ ] closes #54970 (Replace xxxx with the Git...
# 9   - [x] closes #54627\r\n- [x] [Tests added and ...
# 10  ### Pandas version checks\n\n- [X] I have chec...
# 11  ### Feature Type\r\n\r\n- [X] Adding new funct...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13                                               None
# 14  ### Pandas version checks\n\n- [X] I have chec...
# 15  - [ ] closes #54781 (Replace xxxx with the Git...
# 16  ### Feature Type\r\n\r\n- [x] Adding new funct...
# 17  ### Feature Type\n\n- [X] Adding new functiona...
# 18  ### Pandas version checks\r\n\r\n- [X] I have ...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  ### Installation check\n\n- [X] I have read th...
# 21  - [x] closes #54682\r\n- [x] [Tests added and ...
# 22  ### Pandas version checks\r\n\r\n- [X] I have ...
# 23  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 24  ### Pandas version checks\n\n- [X] I have chec...
# 25  ### Pandas version checks\n\n- [X] I have chec...
# 26  ### Feature Type\r\n\r\n- [X] Adding new funct...
# 27  ### Pandas version checks\r\n\r\n- [X] I have ...
# 28  ### Pandas version checks\r\n\r\n- [X] I have ...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   0.0
# 2                       NaN           NaN   0.0
# 3                       NaN           NaN   0.0
# 4                       NaN           NaN   NaN
# 5                       NaN           NaN   NaN
# 6                       NaN           NaN   NaN
# 7                       NaN           NaN   1.0
# 8                       NaN           NaN   0.0
# 9                       NaN           NaN   0.0
# 10                      NaN           NaN   NaN
# 11                      NaN           NaN   NaN
# 12                      NaN           NaN   NaN
# 13                      NaN           NaN   NaN
# 14                      NaN           NaN   NaN
# 15                      NaN           NaN   1.0
# 16                      NaN           NaN   NaN
# 17                      NaN           NaN   NaN
# 18                      NaN           NaN   NaN
# 19                      NaN           NaN   NaN
# 20                      NaN           NaN   NaN
# 21                      NaN           NaN   0.0
# 22                      NaN           NaN   NaN
# 23                      NaN           NaN   NaN
# 24                      NaN           NaN   NaN
# 25                      NaN           NaN   NaN
# 26                      NaN           NaN   NaN
# 27                      NaN           NaN   NaN
# 28                      NaN           NaN   NaN
# 29                      NaN           NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 30 columns]

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data # <Response [200]> means successfully fetched
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55244',
#   'id': 1908834721,
#   'node_id': 'I_kwDOAA0YD85xxoGh',
#   'number': 55244,
#   'title': "BUG: AGAIN!!! pd.to_datetime with dayfirst=True error if 'Jun' in data",
#   'user': {'login': 'madeinjapan',
#    'id': 7633703,
#    'node_id': 'MDQ6VXNlcjc2MzM3MDM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7633703?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/madeinjapan',
#    'html_url': 'https://github.com/madeinjapan',
#    'followers_url': 'https://api.github.com/users/madeinjapan/followers',
#    'following_url': 'https://api.github.com/users/madeinjapan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/madeinjapan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/madeinjapan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/madeinjapan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/madeinjapan/orgs',
#    'repos_url': 'https://api.github.com/users/madeinjapan/repos',
#    'events_url': 'https://api.github.com/users/madeinjapan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/madeinjapan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T12:40:33Z',
#   'updated_at': '2023-09-22T12:48:13Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\n# It works correctly\r\ndatetime_str = [\'01-Jun-2022 00:00:00\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\']\r\npd.to_datetime(pd.Series(datetime_str), dayfirst=True)\r\n\r\n0   2022-06-01 00:00:00\r\n1   2022-06-01 00:00:01\r\n2   2022-06-01 00:00:01\r\n3   2022-06-01 00:00:03\r\n4   2022-06-01 00:00:03\r\n5   2022-06-01 00:00:03\r\ndtype: datetime64[ns]\r\n\r\n# It raise exception\r\ndatetime_str = [\'24-May-2022 08:23:07\', \'24-May-2022 08:23:09\', \'24-May-2022 08:23:09\', \'01-Jun-2022 00:00:00\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\']\r\npd.to_datetime(pd.Series(datetime_str), dayfirst=True)\r\n\r\nValueError: time data "01-Jun-2022 00:00:00" doesn\'t match format "%d-%B-%Y %H:%M:%S", at position 3. You might want to try:\r\n    - passing `format` if your strings have a consistent format;\r\n    - passing `format=\'ISO8601\'` if your strings are all ISO8601 but not necessarily in exactly the same format;\r\n    - passing `format=\'mixed\'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIf the format is not specified as a parameter but dayfirst=True and \'Jun\' is included in the data, we get an esception. If the data contains only \'Jun\', it works correctly.\r\n\r\nExamining the data, the problem may be caused by the following:\r\n```\r\npd.to_datetime(pd.Series([\'24-05-2022 08:23:07\']), dayfirst=True).dt.strftime(\'%B\')\r\n0    May\r\ndtype: object\r\n\r\npd.to_datetime(pd.Series([\'24-05-2022 08:23:07\']), dayfirst=True).dt.strftime(\'%b\')\r\n0    May\r\ndtype: object\r\n```\r\n\r\nso the error is not caused by Jun, but by May, because the short and long names are the same. For this reason, the "%d-%B-%Y %H:%M:%S" format fits it, which in other cases does not.\r\n\r\n### Expected Behavior\r\n\r\nWork with data correctly and quickly. I don\'t have data in a fixed format, what I know, the first value is always the day. So the format cannot be used. Only \'mixed\' could be a solution, but it is very slow... It makes the to_datetime function unusable\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\npyxlsb              : None\r\ns3fs                : None\r\nscipy               : 1.11.1\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : None\r\nxarray              : None\r\nxlrd                : None\r\nzstandard           : None\r\ntzdata              : 2023.3\r\nqtpy                : None\r\npyqt5               : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55243',
#   'id': 1908832035,
#   'node_id': 'PR_kwDOAA0YD85a_NAP',
#   'number': 55243,
#   'title': "BUG: Rolling pd.date_range incorrect for unit='s' #55026",
#   'user': {'login': 'hkhojasteh',
#    'id': 8786747,
#    'node_id': 'MDQ6VXNlcjg3ODY3NDc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8786747?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hkhojasteh',
#    'html_url': 'https://github.com/hkhojasteh',
#    'followers_url': 'https://api.github.com/users/hkhojasteh/followers',
#    'following_url': 'https://api.github.com/users/hkhojasteh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hkhojasteh/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hkhojasteh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hkhojasteh/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hkhojasteh/orgs',
#    'repos_url': 'https://api.github.com/users/hkhojasteh/repos',
#    'events_url': 'https://api.github.com/users/hkhojasteh/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hkhojasteh/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T12:38:42Z',
#   'updated_at': '2023-09-22T12:42:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55243',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55243',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55243.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55243.patch',
#    'merged_at': None},
#   'body': '- [X] closes #55026\r\n- [X] [Tests added and passed]\r\n\r\nThis follows the #55173 and will be fixed by the same approach. The custom tests were added for the `max` function itself.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55241',
#   'id': 1908762323,
#   'node_id': 'PR_kwDOAA0YD85a-9xJ',
#   'number': 55241,
#   'title': 'PERF: Add type-hints in tzconversion.pyx',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 60458168,
#     'node_id': 'MDU6TGFiZWw2MDQ1ODE2OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timezones',
#     'name': 'Timezones',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timezone data dtype'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-22T11:50:25Z',
#   'updated_at': '2023-09-22T12:30:57Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55241',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55241',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55241.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55241.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nPart of #55179. With this, I'm seeing time plummet in the benchmark\r\n\r\n    tslibs.tz_convert.TimeTZConvert.time_tz_localize_to_utc(1000000, tzfile('/usr/share/zoneinfo/Asia/Tokyo'))\r\n\r\nfrom 159ms (Cython 0.29) and 271ms (Cython 3.0.2) to ~5-6ms on both.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55240',
#   'id': 1908707488,
#   'node_id': 'PR_kwDOAA0YD85a-xwP',
#   'number': 55240,
#   'title': 'DOC: point out that explicitly passing axis=None is deprecated for sum, prod, var, std, sem',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T11:11:57Z',
#   'updated_at': '2023-09-22T12:57:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55240',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55240',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55240.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55240.patch',
#    'merged_at': None},
#   'body': '- [x] closes #54547\r\n\r\npointed out in the documentation of the methods: `sum, prod, var, std, sem` that explicitly passing `axis=None` is deprecated.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55239',
#   'id': 1908544863,
#   'node_id': 'I_kwDOAA0YD85xwhVf',
#   'number': 55239,
#   'title': 'DOC: pd to_datetime',
#   'user': {'login': 'PabloRuizCuevas',
#    'id': 48098178,
#    'node_id': 'MDQ6VXNlcjQ4MDk4MTc4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48098178?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PabloRuizCuevas',
#    'html_url': 'https://github.com/PabloRuizCuevas',
#    'followers_url': 'https://api.github.com/users/PabloRuizCuevas/followers',
#    'following_url': 'https://api.github.com/users/PabloRuizCuevas/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PabloRuizCuevas/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PabloRuizCuevas/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PabloRuizCuevas/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PabloRuizCuevas/orgs',
#    'repos_url': 'https://api.github.com/users/PabloRuizCuevas/repos',
#    'events_url': 'https://api.github.com/users/PabloRuizCuevas/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PabloRuizCuevas/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T09:31:43Z',
#   'updated_at': '2023-09-22T09:31:43Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html\n\n### Documentation problem\n\nin pandas to datetime we find that the default value of the parameter exact is:\r\n\r\nexact=_NoDefault.no_default\r\n\r\nwhich i don\'t know what does it mean, on top of that there is inconsistent breaking behavior from last version when parsing:\r\n "%Y-%m-%d" if a date contains   %H:%M:%S so for me they have changed the default value from false to true in pandas v2\n\n### Suggested fix for documentation\n\nProbably now should be true before it was false',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55238',
#   'id': 1908486520,
#   'node_id': 'I_kwDOAA0YD85xwTF4',
#   'number': 55238,
#   'title': "BUG: Union of timezone-aware indices with different units returns index with dtype 'object'",
#   'user': {'login': 'kdebrab',
#    'id': 1150402,
#    'node_id': 'MDQ6VXNlcjExNTA0MDI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1150402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kdebrab',
#    'html_url': 'https://github.com/kdebrab',
#    'followers_url': 'https://api.github.com/users/kdebrab/followers',
#    'following_url': 'https://api.github.com/users/kdebrab/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kdebrab/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kdebrab/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kdebrab/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kdebrab/orgs',
#    'repos_url': 'https://api.github.com/users/kdebrab/repos',
#    'events_url': 'https://api.github.com/users/kdebrab/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kdebrab/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T08:59:34Z',
#   'updated_at': '2023-09-22T09:00:33Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nidx_tz = pd.date_range("2023-1-1", periods=5, freq="H", tz="UTC")\r\npd.Index.union(idx_tz, idx_tz.as_unit("us"))\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nThe above returns:\r\n```\r\nIndex([2023-01-01 00:00:00+00:00, 2023-01-01 01:00:00+00:00,\r\n       2023-01-01 02:00:00+00:00, 2023-01-01 03:00:00+00:00,\r\n       2023-01-01 04:00:00+00:00],\r\n      dtype=\'object\')\r\n```\r\nNote that the dtype is \'object\'.\r\n\r\n### Expected Behavior\r\n\r\nExpected behaviour would be to return an index with dtype \'datetime64[ns, UTC]\'.\r\n\r\nThis is in line with the current behaviour for timezone-naive indices:\r\n```\r\nidx = pd.date_range("2023-1-1", periods=5, freq="H")\r\npd.Index.union(idx, idx.as_unit("us"))\r\n```\r\nwhich gives:\r\n```\r\nDatetimeIndex([\'2023-01-01 00:00:00\', \'2023-01-01 01:00:00\',\r\n               \'2023-01-01 02:00:00\', \'2023-01-01 03:00:00\',\r\n               \'2023-01-01 04:00:00\'],\r\n              dtype=\'datetime64[ns]\', freq=\'H\')\r\n```\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : e86ed377639948c64c429059127bcf5b359ab6be\r\npython              : 3.11.3.final.0\r\npython-bits         : 64\r\nOS                  : Windows\r\nOS-release          : 10\r\nVersion             : 10.0.19044\r\nmachine             : AMD64\r\nprocessor           : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel\r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : None\r\nLOCALE              : English_Belgium.1252\r\npandas              : 2.1.1\r\nnumpy               : 1.26.0\r\npytz                : 2023.3.post1\r\ndateutil            : 2.8.2\r\nsetuptools          : 65.5.0\r\npip                 : 23.2.1\r\nCython              : None\r\npytest              : 7.4.0\r\nhypothesis          : None\r\nsphinx              : None\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : 3.1.4\r\nlxml.etree          : 4.9.3\r\nhtml5lib            : None\r\npymysql             : None\r\npsycopg2            : None\r\njinja2              : 3.1.2\r\nIPython             : 8.13.2\r\npandas_datareader   : None\r\nbs4                 : None\r\nbottleneck          : 1.3.7\r\ndataframe-api-compat: None\r\nfastparquet         : None\r\nfsspec              : 2023.5.0\r\ngcsfs               : None\r\nmatplotlib          : 3.7.2\r\nnumba               : None\r\nnumexpr             : 2.8.6\r\nodfpy               : None\r\nopenpyxl            : 3.1.2\r\npandas_gbq          : None\r\npyarrow             : 13.0.0\r\npyreadstat          : None\r\npyxlsb              : 1.0.10\r\ns3fs                : None\r\nscipy               : 1.11.2\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : 0.9.0\r\nxarray              : 2023.5.0\r\nxlrd                : 2.0.1\r\nzstandard           : None\r\ntzdata              : 2023.3\r\nqtpy                : None\r\npyqt5               : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55237',
#   'id': 1908486300,
#   'node_id': 'I_kwDOAA0YD85xwTCc',
#   'number': 55237,
#   'title': 'ENH: Bring back the observed argument for groupby on Categorical columns',
#   'user': {'login': 'nick-maykr',
#    'id': 75306162,
#    'node_id': 'MDQ6VXNlcjc1MzA2MTYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75306162?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nick-maykr',
#    'html_url': 'https://github.com/nick-maykr',
#    'followers_url': 'https://api.github.com/users/nick-maykr/followers',
#    'following_url': 'https://api.github.com/users/nick-maykr/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/nick-maykr/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/nick-maykr/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/nick-maykr/subscriptions',
#    'organizations_url': 'https://api.github.com/users/nick-maykr/orgs',
#    'repos_url': 'https://api.github.com/users/nick-maykr/repos',
#    'events_url': 'https://api.github.com/users/nick-maykr/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/nick-maykr/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-22T08:59:25Z',
#   'updated_at': '2023-09-22T09:19:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [x] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nHi! \r\nThe reasons for deprecation of this parameter are nowhere to be found, so I'm curious whether a discussion took place.\n\n### Feature Description\n\nAfter upgrading to 2.1 I have to replace my old code\r\n```\r\nsample_distribution = df.sample(n).groupby(categorical_cols).size()\r\n```\r\nwith this:\r\n```\r\nmain_distribution = df.groupby(categorical_cols).size()\r\nsample_distribution = df.sample(n).groupby(categorical_cols).size().reindex(main_distribution.index, fill_value=0)\r\n```\n\n### Alternative Solutions\n\nChanging the default value of `observed` to True is fine I guess, but the ability to use `False` was indeed convenient. Maybe we should bring it back?)\n\n### Additional Context\n\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55236',
#   'id': 1908063353,
#   'node_id': 'PR_kwDOAA0YD85a8mqg',
#   'number': 55236,
#   'title': 'DOC: Fix doc for first_valid_index',
#   'user': {'login': 'jfadia',
#    'id': 90651438,
#    'node_id': 'MDQ6VXNlcjkwNjUxNDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90651438?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jfadia',
#    'html_url': 'https://github.com/jfadia',
#    'followers_url': 'https://api.github.com/users/jfadia/followers',
#    'following_url': 'https://api.github.com/users/jfadia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jfadia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jfadia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jfadia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jfadia/orgs',
#    'repos_url': 'https://api.github.com/users/jfadia/repos',
#    'events_url': 'https://api.github.com/users/jfadia/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jfadia/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T02:00:41Z',
#   'updated_at': '2023-09-22T02:02:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55236',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55236',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55236.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55236.patch',
#    'merged_at': None},
#   'body': '- [x] closes #55187\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55235',
#   'id': 1908018573,
#   'node_id': 'PR_kwDOAA0YD85a8eBb',
#   'number': 55235,
#   'title': 'DEPR: Change FutureWarning for observed=False to DeprecationWarning',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/111',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111/labels',
#    'id': 9940315,
#    'node_id': 'MI_kwDOAA0YD84Al61b',
#    'number': 111,
#    'title': '2.1.2',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 0,
#    'state': 'open',
#    'created_at': '2023-09-19T23:42:34Z',
#    'updated_at': '2023-09-22T02:37:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2023-09-22T01:22:05Z',
#   'updated_at': '2023-09-22T02:21:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55235',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55235',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55235.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55235.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #54970 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55234',
#   'id': 1907999408,
#   'node_id': 'PR_kwDOAA0YD85a8aAA',
#   'number': 55234,
#   'title': 'BUG/ENH: Use pyarrow grouped aggregation functions for pyarrow-backed groupby ops',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/109',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/109',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/109/labels',
#    'id': 9785210,
#    'node_id': 'MI_kwDOAA0YD84AlU96',
#    'number': 109,
#    'title': '2.2',
#    'description': '',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 11,
#    'closed_issues': 163,
#    'state': 'open',
#    'created_at': '2023-08-13T07:21:54Z',
#    'updated_at': '2023-09-22T02:30:53Z',
#    'due_on': '2023-12-20T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-09-22T01:04:09Z',
#   'updated_at': '2023-09-22T03:26:06Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55234',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55234',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55234.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55234.patch',
#    'merged_at': None},
#   'body': '- [x] closes #54627\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nUse pyarrow\'s `TableGroupBy` functionality for pyarrow-backed groupby aggregations.\r\n\r\nThis has a few benefits over the current approach of round-tripping through non-arrow dtypes:\r\n1. proper support for groupby operations with pyarrrow decimal types\r\n2. removes values-dependent behavior (e.g. https://github.com/pandas-dev/pandas/issues/54627#issuecomment-1684160350)\r\n3. aligns grouped aggregation behavior with non-grouped aggregation behavior (existing implementation has a number of subtle differences)\r\n\r\nPerformance impact is mixed. I think the consistency benefits mentioned above outweigh the performance impact here. If others disagree, we could continue using the pandas implementation for specific aggregations. \r\n\r\nNote: These timings are from a slow laptop. It would be great if someone could run this ASV to confirm (@rhshadrach possibly?)\r\n\r\n`asv continuous -f 1.1 upstream/main arrow-groupby -b groupby.GroupByAggregateArrowDtypes`\r\n\r\n```\r\n           before            after    ratio\r\n+      32.3±0.9ms         54.8±3ms     1.70  groupby.GroupByAggregateArrowDtypes.time_frame_agg(int32[pyarrow], \'all\')\r\n+        35.3±1ms         51.4±2ms     1.46  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'any\')\r\n+        36.1±1ms       50.2±0.9ms     1.39  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'all\')\r\n+        39.8±6ms         54.6±2ms     1.37  groupby.GroupByAggregateArrowDtypes.time_frame_agg(int32[pyarrow], \'any\')\r\n+        42.6±2ms         57.1±3ms     1.34  groupby.GroupByAggregateArrowDtypes.time_frame_agg(bool[pyarrow], \'min\')\r\n+      42.5±0.9ms         54.2±6ms     1.28  groupby.GroupByAggregateArrowDtypes.time_frame_agg(timestamp[s, tz=UTC][pyarrow], \'min\')\r\n+        40.7±3ms         51.4±3ms     1.26  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'max\')\r\n+        40.9±2ms         50.8±4ms     1.24  groupby.GroupByAggregateArrowDtypes.time_frame_agg(timestamp[s, tz=UTC][pyarrow], \'max\')\r\n+        46.2±3ms         56.4±2ms     1.22  groupby.GroupByAggregateArrowDtypes.time_frame_agg(bool[pyarrow], \'std\')\r\n+        41.4±2ms         49.3±1ms     1.19  groupby.GroupByAggregateArrowDtypes.time_frame_agg(int32[pyarrow], \'std\')\r\n+        43.3±2ms         50.7±1ms     1.17  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'min\')\r\n-        427±80ms          128±4ms     0.30  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'prod\')\r\n-        395±40ms         91.3±6ms     0.23  groupby.GroupByAggregateArrowDtypes.time_frame_agg(string[pyarrow], \'max\')\r\n-         401±9ms         89.3±3ms     0.22  groupby.GroupByAggregateArrowDtypes.time_frame_agg(string[pyarrow], \'min\')\r\n-        429±50ms         89.0±8ms     0.21  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'max\')\r\n-        449±80ms         89.1±2ms     0.20  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'min\')\r\n-        384±60ms         56.1±2ms     0.15  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'sum\')\r\n-        442±80ms         56.6±2ms     0.13  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'mean\')\r ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55232',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55232/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55232/comments',
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55196/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55196/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55194',
#   'id': 1902350703,
#   'node_id': 'I_kwDOAA0YD85xY5Fv',
#   'number': 55194,
#   'title': 'BUG: `DataFrame.var()` with `axis=1` returns `object` Series instead of `float64` Series?',
#   'user': {'login': 'itholic',
#    'id': 44108233,
#    'node_id': 'MDQ6VXNlcjQ0MTA4MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44108233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/itholic',
#    'html_url': 'https://github.com/itholic',
#    'followers_url': 'https://api.github.com/users/itholic/followers',
#    'following_url': 'https://api.github.com/users/itholic/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/itholic/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/itholic/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/itholic/subscriptions',
#    'organizations_url': 'https://api.github.com/users/itholic/orgs',
#    'repos_url': 'https://api.github.com/users/itholic/repos',
#    'events_url': 'https://api.github.com/users/itholic/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/itholic/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/111',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111/labels',
#    'id': 9940315,
#    'node_id': 'MI_kwDOAA0YD84Al61b',
#    'number': 111,
#    'title': '2.1.2',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 0,
#    'state': 'open',
#    'created_at': '2023-09-19T23:42:34Z',
#    'updated_at': '2023-09-22T02:37:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2023-09-19T07:11:15Z',
#   'updated_at': '2023-09-21T12:25:49Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\npdf = pd.DataFrame(\r\n    {\r\n        "A": [1, -2, 3, -4, 5] * 300,\r\n        "B": [1.0, -2, 3, -4, 5] * 300,\r\n        "C": [-6.0, -7, -8, -9, 10] * 300,\r\n        "D": [True, False, True, False, False] * 300,\r\n    },\r\n    index=range(10, 15001, 10),\r\n)\r\npdf.var(axis=1)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\n`DataFrame.var()` with `axis=1` returns `float64` Series in Pandas 1.5.3, but now it returns `object` Series instead. So I wonder if it is an intended behavior or an unexpected bug:\r\n\r\n**Pandas 1.5.3**\r\n```python\r\n>>> pdf = pd.DataFrame(\r\n...     {\r\n...         "A": [1, -2, 3, -4, 5] * 300,\r\n...         "B": [1.0, -2, 3, -4, 5] * 300,\r\n...         "C": [-6.0, -7, -8, -9, 10] * 300,\r\n...         "D": [True, False, True, False, False] * 300,\r\n...     },\r\n...     index=range(10, 15001, 10),\r\n... )\r\n>>> pdf.var(axis=1)\r\n10       12.250000\r\n20        8.916667\r\n30       27.583333\r\n40       13.583333\r\n50       16.666667\r\n           ...\r\n14960    12.250000\r\n14970     8.916667\r\n14980    27.583333\r\n14990    13.583333\r\n15000    16.666667\r\nLength: 1500, dtype: float64\r\n```\r\n\r\n**Pandas 2.0.0 and above**\r\n```python\r\n>>> pdf = pd.DataFrame(\r\n...     {\r\n...         "A": [1, -2, 3, -4, 5] * 300,\r\n...         "B": [1.0, -2, 3, -4, 5] * 300,\r\n...         "C": [-6.0, -7, -8, -9, 10] * 300,\r\n...         "D": [True, False, True, False, False] * 300,\r\n...     },\r\n...     index=range(10, 15001, 10),\r\n... )\r\n>>> pdf.var(axis=1)\r\n10           12.25\r\n20        8.916667\r\n30       27.583333\r\n40       13.583333\r\n50       16.666667\r\n           ...\r\n14960        12.25\r\n14970     8.916667\r\n14980    27.583333\r\n14990    13.583333\r\n15000    16.666667\r\nLength: 1500, dtype: object\r\n```\r\n\r\n### Expected Behavior\r\n\r\n```python\r\n>>> pdf = pd.DataFrame(\r\n...     {\r\n...         "A": [1, -2, 3, -4, 5] * 300,\r\n...         "B": [1.0, -2, 3, -4, 5] * 300,\r\n...         "C": [-6.0, -7, -8, -9, 10] * 300,\r\n...         "D": [True, False, True, False, False] * 300,\r\n...     },\r\n...     index=range(10, 15001, 10),\r\n... )\r\n>>> pdf.var(axis=1)\r\n10       12.250000\r\n20        8.916667\r\n30       27.583333\r\n40       13.583333\r\n50       16.666667\r\n           ...\r\n14960    12.250000\r\n14970     8.916667\r\n14980    27.583333\r\n14990    13.583333\r\n15000    16.666667\r\nLength: 1500, dtype: float64\r\n```\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : ba1cccd19da778f0c3a7d6a885685da16a072870\r\npython              : 3.9.17.final.0\r\npython-bits         : 64\r\nOS                  : Darwin\r\nOS-release          : 22.6.0\r\nVersion             : Darwin Kernel Version 22.6.0: Wed Jul  5 22:21:53 PDT 2023; root:xnu-8796.141.3~6/RELEASE_ARM64_T6020\r\nmachine             : arm64\r\nprocessor           : arm\r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : None\r\nLOCALE              : None.UTF-8\r\n\r\npandas              : 2.1.0\r\nnumpy               : 1.26.0\r\npytz                : 2023.3\r\ndateutil            : 2.8.2\r\nsetuptools          : 68.0.0\r\npip                 : 23.2.1\r\nCython              : None\r\npytest              : 7.4.0\r\nhypothesis          : None\r\nsphinx              : 3.0.4\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : None\r\nlxml.etre ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55187',
#   'id': 1901561244,
#   'node_id': 'I_kwDOAA0YD85xV4Wc',
#   'number': 55187,
#   'title': 'DOC: ',
#   'user': {'login': 'alexandermorgan',
#    'id': 2601689,
#    'node_id': 'MDQ6VXNlcjI2MDE2ODk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2601689?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexandermorgan',
#    'html_url': 'https://github.com/alexandermorgan',
#    'followers_url': 'https://api.github.com/users/alexandermorgan/followers',
#    'following_url': 'https://api.github.com/users/alexandermorgan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alexandermorgan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alexandermorgan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alexandermorgan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alexandermorgan/orgs',
#    'repos_url': 'https://api.github.com/users/alexandermorgan/repos',
#    'events_url': 'https://api.github.com/users/alexandermorgan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alexandermorgan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'jfadia',
#    'id': 90651438,
#    'node_id': 'MDQ6VXNlcjkwNjUxNDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90651438?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jfadia',
#    'html_url': 'https://github.com/jfadia',
#    'followers_url': 'https://api.github.com/users/jfadia/followers',
#    'following_url': 'https://api.github.com/users/jfadia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jfadia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jfadia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jfadia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jfadia/orgs',
#    'repos_url': 'https://api.github.com/users/jfadia/repos',
#    'events_url': 'https://api.github.com/users/jfadia/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jfadia/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jfadia',
#     'id': 90651438,
#     'node_id': 'MDQ6VXNlcjkwNjUxNDM4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/90651438?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jfadia',
#     'html_url': 'https://github.com/jfadia',
#     'followers_url': 'https://api.github.com/users/jfadia/followers',
#     'following_url': 'https://api.github.com/users/jfadia/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jfadia/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jfadia/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jfadia/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jfadia/orgs',
#     'repos_url': 'https://api.github.com/users/jfadia/repos',
#     'events_url': 'https://api.github.com/users/jfadia/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jfadia/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-09-18T18:58:00Z',
#   'updated_at': '2023-09-22T01:49:33Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\npandas.Series.first_valid_index\r\nhttps://github.com/pandas-dev/pandas/blob/ba1cccd19da778f0c3a7d6a885685da16a072870/pandas/core/generic.py#L12341\n\n### Documentation problem\n\nhttps://github.com/pandas-dev/pandas/blob/ba1cccd19da778f0c3a7d6a885685da16a072870/pandas/core/generic.py#L12341\r\nThe "Notes" passage reads: "If all elements are non-NA/null, returns None. Also returns None for empty Series/DataFrame."\r\nbut the "non-" should not be there.\n\n### Suggested fix for documentation\n\nThe "non-" should be deleted from the "Notes" section, resulting in this:\r\n"If all elements are NA/null, returns None. Also returns None for empty Series/DataFrame."',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 7633703
# 8786747
# 45562402
# 91160475
# 48098178
# 1150402
# 75306162
# 90651438
# 47963215
# 8519523
# 1804856
# 5097759
# 30196
# 47963215
# 12795317
# 33491632
# 95344621
# 1224492
# 37224102
# 16261897
# 136445532
# 91896754
# 30691708
# 20618587
# 62142979
# 47388301
# 19430969
# 24544692
# 44108233
# 2601689

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55244',
#   'id': 1908834721,
#   'node_id': 'I_kwDOAA0YD85xxoGh',
#   'number': 55244,
#   'title': "BUG: AGAIN!!! pd.to_datetime with dayfirst=True error if 'Jun' in data",
#   'user': {'login': 'madeinjapan',
#    'id': 7633703,
#    'node_id': 'MDQ6VXNlcjc2MzM3MDM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7633703?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/madeinjapan',
#    'html_url': 'https://github.com/madeinjapan',
#    'followers_url': 'https://api.github.com/users/madeinjapan/followers',
#    'following_url': 'https://api.github.com/users/madeinjapan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/madeinjapan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/madeinjapan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/madeinjapan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/madeinjapan/orgs',
#    'repos_url': 'https://api.github.com/users/madeinjapan/repos',
#    'events_url': 'https://api.github.com/users/madeinjapan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/madeinjapan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T12:40:33Z',
#   'updated_at': '2023-09-22T12:48:13Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\n# It works correctly\r\ndatetime_str = [\'01-Jun-2022 00:00:00\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\']\r\npd.to_datetime(pd.Series(datetime_str), dayfirst=True)\r\n\r\n0   2022-06-01 00:00:00\r\n1   2022-06-01 00:00:01\r\n2   2022-06-01 00:00:01\r\n3   2022-06-01 00:00:03\r\n4   2022-06-01 00:00:03\r\n5   2022-06-01 00:00:03\r\ndtype: datetime64[ns]\r\n\r\n# It raise exception\r\ndatetime_str = [\'24-May-2022 08:23:07\', \'24-May-2022 08:23:09\', \'24-May-2022 08:23:09\', \'01-Jun-2022 00:00:00\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:01\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\', \'01-Jun-2022 00:00:03\']\r\npd.to_datetime(pd.Series(datetime_str), dayfirst=True)\r\n\r\nValueError: time data "01-Jun-2022 00:00:00" doesn\'t match format "%d-%B-%Y %H:%M:%S", at position 3. You might want to try:\r\n    - passing `format` if your strings have a consistent format;\r\n    - passing `format=\'ISO8601\'` if your strings are all ISO8601 but not necessarily in exactly the same format;\r\n    - passing `format=\'mixed\'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIf the format is not specified as a parameter but dayfirst=True and \'Jun\' is included in the data, we get an esception. If the data contains only \'Jun\', it works correctly.\r\n\r\nExamining the data, the problem may be caused by the following:\r\n```\r\npd.to_datetime(pd.Series([\'24-05-2022 08:23:07\']), dayfirst=True).dt.strftime(\'%B\')\r\n0    May\r\ndtype: object\r\n\r\npd.to_datetime(pd.Series([\'24-05-2022 08:23:07\']), dayfirst=True).dt.strftime(\'%b\')\r\n0    May\r\ndtype: object\r\n```\r\n\r\nso the error is not caused by Jun, but by May, because the short and long names are the same. For this reason, the "%d-%B-%Y %H:%M:%S" format fits it, which in other cases does not.\r\n\r\n### Expected Behavior\r\n\r\nWork with data correctly and quickly. I don\'t have data in a fixed format, what I know, the first value is always the day. So the format cannot be used. Only \'mixed\' could be a solution, but it is very slow... It makes the to_datetime function unusable\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\npyxlsb              : None\r\ns3fs                : None\r\nscipy               : 1.11.1\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : None\r\nxarray              : None\r\nxlrd                : None\r\nzstandard           : None\r\ntzdata              : 2023.3\r\nqtpy                : None\r\npyqt5               : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55244/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55243',
#   'id': 1908832035,
#   'node_id': 'PR_kwDOAA0YD85a_NAP',
#   'number': 55243,
#   'title': "BUG: Rolling pd.date_range incorrect for unit='s' #55026",
#   'user': {'login': 'hkhojasteh',
#    'id': 8786747,
#    'node_id': 'MDQ6VXNlcjg3ODY3NDc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8786747?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hkhojasteh',
#    'html_url': 'https://github.com/hkhojasteh',
#    'followers_url': 'https://api.github.com/users/hkhojasteh/followers',
#    'following_url': 'https://api.github.com/users/hkhojasteh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hkhojasteh/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hkhojasteh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hkhojasteh/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hkhojasteh/orgs',
#    'repos_url': 'https://api.github.com/users/hkhojasteh/repos',
#    'events_url': 'https://api.github.com/users/hkhojasteh/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hkhojasteh/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T12:38:42Z',
#   'updated_at': '2023-09-22T12:42:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55243',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55243',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55243.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55243.patch',
#    'merged_at': None},
#   'body': '- [X] closes #55026\r\n- [X] [Tests added and passed]\r\n\r\nThis follows the #55173 and will be fixed by the same approach. The custom tests were added for the `max` function itself.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55243/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55241',
#   'id': 1908762323,
#   'node_id': 'PR_kwDOAA0YD85a-9xJ',
#   'number': 55241,
#   'title': 'PERF: Add type-hints in tzconversion.pyx',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 60458168,
#     'node_id': 'MDU6TGFiZWw2MDQ1ODE2OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timezones',
#     'name': 'Timezones',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timezone data dtype'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-22T11:50:25Z',
#   'updated_at': '2023-09-22T12:30:57Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55241',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55241',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55241.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55241.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nPart of #55179. With this, I'm seeing time plummet in the benchmark\r\n\r\n    tslibs.tz_convert.TimeTZConvert.time_tz_localize_to_utc(1000000, tzfile('/usr/share/zoneinfo/Asia/Tokyo'))\r\n\r\nfrom 159ms (Cython 0.29) and 271ms (Cython 3.0.2) to ~5-6ms on both.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55241/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55240',
#   'id': 1908707488,
#   'node_id': 'PR_kwDOAA0YD85a-xwP',
#   'number': 55240,
#   'title': 'DOC: point out that explicitly passing axis=None is deprecated for sum, prod, var, std, sem',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T11:11:57Z',
#   'updated_at': '2023-09-22T12:57:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55240',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55240',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55240.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55240.patch',
#    'merged_at': None},
#   'body': '- [x] closes #54547\r\n\r\npointed out in the documentation of the methods: `sum, prod, var, std, sem` that explicitly passing `axis=None` is deprecated.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55240/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55239',
#   'id': 1908544863,
#   'node_id': 'I_kwDOAA0YD85xwhVf',
#   'number': 55239,
#   'title': 'DOC: pd to_datetime',
#   'user': {'login': 'PabloRuizCuevas',
#    'id': 48098178,
#    'node_id': 'MDQ6VXNlcjQ4MDk4MTc4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48098178?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PabloRuizCuevas',
#    'html_url': 'https://github.com/PabloRuizCuevas',
#    'followers_url': 'https://api.github.com/users/PabloRuizCuevas/followers',
#    'following_url': 'https://api.github.com/users/PabloRuizCuevas/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PabloRuizCuevas/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PabloRuizCuevas/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PabloRuizCuevas/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PabloRuizCuevas/orgs',
#    'repos_url': 'https://api.github.com/users/PabloRuizCuevas/repos',
#    'events_url': 'https://api.github.com/users/PabloRuizCuevas/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PabloRuizCuevas/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T09:31:43Z',
#   'updated_at': '2023-09-22T09:31:43Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html\n\n### Documentation problem\n\nin pandas to datetime we find that the default value of the parameter exact is:\r\n\r\nexact=_NoDefault.no_default\r\n\r\nwhich i don\'t know what does it mean, on top of that there is inconsistent breaking behavior from last version when parsing:\r\n "%Y-%m-%d" if a date contains   %H:%M:%S so for me they have changed the default value from false to true in pandas v2\n\n### Suggested fix for documentation\n\nProbably now should be true before it was false',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55239/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55238',
#   'id': 1908486520,
#   'node_id': 'I_kwDOAA0YD85xwTF4',
#   'number': 55238,
#   'title': "BUG: Union of timezone-aware indices with different units returns index with dtype 'object'",
#   'user': {'login': 'kdebrab',
#    'id': 1150402,
#    'node_id': 'MDQ6VXNlcjExNTA0MDI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1150402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kdebrab',
#    'html_url': 'https://github.com/kdebrab',
#    'followers_url': 'https://api.github.com/users/kdebrab/followers',
#    'following_url': 'https://api.github.com/users/kdebrab/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kdebrab/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kdebrab/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kdebrab/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kdebrab/orgs',
#    'repos_url': 'https://api.github.com/users/kdebrab/repos',
#    'events_url': 'https://api.github.com/users/kdebrab/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kdebrab/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T08:59:34Z',
#   'updated_at': '2023-09-22T09:00:33Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nidx_tz = pd.date_range("2023-1-1", periods=5, freq="H", tz="UTC")\r\npd.Index.union(idx_tz, idx_tz.as_unit("us"))\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nThe above returns:\r\n```\r\nIndex([2023-01-01 00:00:00+00:00, 2023-01-01 01:00:00+00:00,\r\n       2023-01-01 02:00:00+00:00, 2023-01-01 03:00:00+00:00,\r\n       2023-01-01 04:00:00+00:00],\r\n      dtype=\'object\')\r\n```\r\nNote that the dtype is \'object\'.\r\n\r\n### Expected Behavior\r\n\r\nExpected behaviour would be to return an index with dtype \'datetime64[ns, UTC]\'.\r\n\r\nThis is in line with the current behaviour for timezone-naive indices:\r\n```\r\nidx = pd.date_range("2023-1-1", periods=5, freq="H")\r\npd.Index.union(idx, idx.as_unit("us"))\r\n```\r\nwhich gives:\r\n```\r\nDatetimeIndex([\'2023-01-01 00:00:00\', \'2023-01-01 01:00:00\',\r\n               \'2023-01-01 02:00:00\', \'2023-01-01 03:00:00\',\r\n               \'2023-01-01 04:00:00\'],\r\n              dtype=\'datetime64[ns]\', freq=\'H\')\r\n```\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : e86ed377639948c64c429059127bcf5b359ab6be\r\npython              : 3.11.3.final.0\r\npython-bits         : 64\r\nOS                  : Windows\r\nOS-release          : 10\r\nVersion             : 10.0.19044\r\nmachine             : AMD64\r\nprocessor           : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel\r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : None\r\nLOCALE              : English_Belgium.1252\r\npandas              : 2.1.1\r\nnumpy               : 1.26.0\r\npytz                : 2023.3.post1\r\ndateutil            : 2.8.2\r\nsetuptools          : 65.5.0\r\npip                 : 23.2.1\r\nCython              : None\r\npytest              : 7.4.0\r\nhypothesis          : None\r\nsphinx              : None\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : 3.1.4\r\nlxml.etree          : 4.9.3\r\nhtml5lib            : None\r\npymysql             : None\r\npsycopg2            : None\r\njinja2              : 3.1.2\r\nIPython             : 8.13.2\r\npandas_datareader   : None\r\nbs4                 : None\r\nbottleneck          : 1.3.7\r\ndataframe-api-compat: None\r\nfastparquet         : None\r\nfsspec              : 2023.5.0\r\ngcsfs               : None\r\nmatplotlib          : 3.7.2\r\nnumba               : None\r\nnumexpr             : 2.8.6\r\nodfpy               : None\r\nopenpyxl            : 3.1.2\r\npandas_gbq          : None\r\npyarrow             : 13.0.0\r\npyreadstat          : None\r\npyxlsb              : 1.0.10\r\ns3fs                : None\r\nscipy               : 1.11.2\r\nsqlalchemy          : None\r\ntables              : None\r\ntabulate            : 0.9.0\r\nxarray              : 2023.5.0\r\nxlrd                : 2.0.1\r\nzstandard           : None\r\ntzdata              : 2023.3\r\nqtpy                : None\r\npyqt5               : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55238/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55237',
#   'id': 1908486300,
#   'node_id': 'I_kwDOAA0YD85xwTCc',
#   'number': 55237,
#   'title': 'ENH: Bring back the observed argument for groupby on Categorical columns',
#   'user': {'login': 'nick-maykr',
#    'id': 75306162,
#    'node_id': 'MDQ6VXNlcjc1MzA2MTYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75306162?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nick-maykr',
#    'html_url': 'https://github.com/nick-maykr',
#    'followers_url': 'https://api.github.com/users/nick-maykr/followers',
#    'following_url': 'https://api.github.com/users/nick-maykr/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/nick-maykr/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/nick-maykr/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/nick-maykr/subscriptions',
#    'organizations_url': 'https://api.github.com/users/nick-maykr/orgs',
#    'repos_url': 'https://api.github.com/users/nick-maykr/repos',
#    'events_url': 'https://api.github.com/users/nick-maykr/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/nick-maykr/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-22T08:59:25Z',
#   'updated_at': '2023-09-22T09:19:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [x] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nHi! \r\nThe reasons for deprecation of this parameter are nowhere to be found, so I'm curious whether a discussion took place.\n\n### Feature Description\n\nAfter upgrading to 2.1 I have to replace my old code\r\n```\r\nsample_distribution = df.sample(n).groupby(categorical_cols).size()\r\n```\r\nwith this:\r\n```\r\nmain_distribution = df.groupby(categorical_cols).size()\r\nsample_distribution = df.sample(n).groupby(categorical_cols).size().reindex(main_distribution.index, fill_value=0)\r\n```\n\n### Alternative Solutions\n\nChanging the default value of `observed` to True is fine I guess, but the ability to use `False` was indeed convenient. Maybe we should bring it back?)\n\n### Additional Context\n\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55237/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55236',
#   'id': 1908063353,
#   'node_id': 'PR_kwDOAA0YD85a8mqg',
#   'number': 55236,
#   'title': 'DOC: Fix doc for first_valid_index',
#   'user': {'login': 'jfadia',
#    'id': 90651438,
#    'node_id': 'MDQ6VXNlcjkwNjUxNDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90651438?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jfadia',
#    'html_url': 'https://github.com/jfadia',
#    'followers_url': 'https://api.github.com/users/jfadia/followers',
#    'following_url': 'https://api.github.com/users/jfadia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jfadia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jfadia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jfadia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jfadia/orgs',
#    'repos_url': 'https://api.github.com/users/jfadia/repos',
#    'events_url': 'https://api.github.com/users/jfadia/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jfadia/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-09-22T02:00:41Z',
#   'updated_at': '2023-09-22T02:02:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55236',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55236',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55236.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55236.patch',
#    'merged_at': None},
#   'body': '- [x] closes #55187\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55236/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55235',
#   'id': 1908018573,
#   'node_id': 'PR_kwDOAA0YD85a8eBb',
#   'number': 55235,
#   'title': 'DEPR: Change FutureWarning for observed=False to DeprecationWarning',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/111',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111/labels',
#    'id': 9940315,
#    'node_id': 'MI_kwDOAA0YD84Al61b',
#    'number': 111,
#    'title': '2.1.2',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 0,
#    'state': 'open',
#    'created_at': '2023-09-19T23:42:34Z',
#    'updated_at': '2023-09-22T02:37:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2023-09-22T01:22:05Z',
#   'updated_at': '2023-09-22T02:21:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55235',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55235',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55235.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55235.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #54970 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55235/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55234',
#   'id': 1907999408,
#   'node_id': 'PR_kwDOAA0YD85a8aAA',
#   'number': 55234,
#   'title': 'BUG/ENH: Use pyarrow grouped aggregation functions for pyarrow-backed groupby ops',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/109',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/109',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/109/labels',
#    'id': 9785210,
#    'node_id': 'MI_kwDOAA0YD84AlU96',
#    'number': 109,
#    'title': '2.2',
#    'description': '',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 11,
#    'closed_issues': 163,
#    'state': 'open',
#    'created_at': '2023-08-13T07:21:54Z',
#    'updated_at': '2023-09-22T02:30:53Z',
#    'due_on': '2023-12-20T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-09-22T01:04:09Z',
#   'updated_at': '2023-09-22T03:26:06Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55234',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/55234',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/55234.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/55234.patch',
#    'merged_at': None},
#   'body': '- [x] closes #54627\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nUse pyarrow\'s `TableGroupBy` functionality for pyarrow-backed groupby aggregations.\r\n\r\nThis has a few benefits over the current approach of round-tripping through non-arrow dtypes:\r\n1. proper support for groupby operations with pyarrrow decimal types\r\n2. removes values-dependent behavior (e.g. https://github.com/pandas-dev/pandas/issues/54627#issuecomment-1684160350)\r\n3. aligns grouped aggregation behavior with non-grouped aggregation behavior (existing implementation has a number of subtle differences)\r\n\r\nPerformance impact is mixed. I think the consistency benefits mentioned above outweigh the performance impact here. If others disagree, we could continue using the pandas implementation for specific aggregations. \r\n\r\nNote: These timings are from a slow laptop. It would be great if someone could run this ASV to confirm (@rhshadrach possibly?)\r\n\r\n`asv continuous -f 1.1 upstream/main arrow-groupby -b groupby.GroupByAggregateArrowDtypes`\r\n\r\n```\r\n           before            after    ratio\r\n+      32.3±0.9ms         54.8±3ms     1.70  groupby.GroupByAggregateArrowDtypes.time_frame_agg(int32[pyarrow], \'all\')\r\n+        35.3±1ms         51.4±2ms     1.46  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'any\')\r\n+        36.1±1ms       50.2±0.9ms     1.39  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'all\')\r\n+        39.8±6ms         54.6±2ms     1.37  groupby.GroupByAggregateArrowDtypes.time_frame_agg(int32[pyarrow], \'any\')\r\n+        42.6±2ms         57.1±3ms     1.34  groupby.GroupByAggregateArrowDtypes.time_frame_agg(bool[pyarrow], \'min\')\r\n+      42.5±0.9ms         54.2±6ms     1.28  groupby.GroupByAggregateArrowDtypes.time_frame_agg(timestamp[s, tz=UTC][pyarrow], \'min\')\r\n+        40.7±3ms         51.4±3ms     1.26  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'max\')\r\n+        40.9±2ms         50.8±4ms     1.24  groupby.GroupByAggregateArrowDtypes.time_frame_agg(timestamp[s, tz=UTC][pyarrow], \'max\')\r\n+        46.2±3ms         56.4±2ms     1.22  groupby.GroupByAggregateArrowDtypes.time_frame_agg(bool[pyarrow], \'std\')\r\n+        41.4±2ms         49.3±1ms     1.19  groupby.GroupByAggregateArrowDtypes.time_frame_agg(int32[pyarrow], \'std\')\r\n+        43.3±2ms         50.7±1ms     1.17  groupby.GroupByAggregateArrowDtypes.time_frame_agg(duration[ms][pyarrow], \'min\')\r\n-        427±80ms          128±4ms     0.30  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'prod\')\r\n-        395±40ms         91.3±6ms     0.23  groupby.GroupByAggregateArrowDtypes.time_frame_agg(string[pyarrow], \'max\')\r\n-         401±9ms         89.3±3ms     0.22  groupby.GroupByAggregateArrowDtypes.time_frame_agg(string[pyarrow], \'min\')\r\n-        429±50ms         89.0±8ms     0.21  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'max\')\r\n-        449±80ms         89.1±2ms     0.20  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'min\')\r\n-        384±60ms         56.1±2ms     0.15  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'sum\')\r\n-        442±80ms         56.6±2ms     0.13  groupby.GroupByAggregateArrowDtypes.time_frame_agg(decimal128(25, 3)[pyarrow], \'mean\')\r ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55234/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55232',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55232/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55232/comments',
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55196/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55196/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55194',
#   'id': 1902350703,
#   'node_id': 'I_kwDOAA0YD85xY5Fv',
#   'number': 55194,
#   'title': 'BUG: `DataFrame.var()` with `axis=1` returns `object` Series instead of `float64` Series?',
#   'user': {'login': 'itholic',
#    'id': 44108233,
#    'node_id': 'MDQ6VXNlcjQ0MTA4MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44108233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/itholic',
#    'html_url': 'https://github.com/itholic',
#    'followers_url': 'https://api.github.com/users/itholic/followers',
#    'following_url': 'https://api.github.com/users/itholic/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/itholic/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/itholic/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/itholic/subscriptions',
#    'organizations_url': 'https://api.github.com/users/itholic/orgs',
#    'repos_url': 'https://api.github.com/users/itholic/repos',
#    'events_url': 'https://api.github.com/users/itholic/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/itholic/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/111',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/111/labels',
#    'id': 9940315,
#    'node_id': 'MI_kwDOAA0YD84Al61b',
#    'number': 111,
#    'title': '2.1.2',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 22,
#    'closed_issues': 0,
#    'state': 'open',
#    'created_at': '2023-09-19T23:42:34Z',
#    'updated_at': '2023-09-22T02:37:45Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2023-09-19T07:11:15Z',
#   'updated_at': '2023-09-21T12:25:49Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\npdf = pd.DataFrame(\r\n    {\r\n        "A": [1, -2, 3, -4, 5] * 300,\r\n        "B": [1.0, -2, 3, -4, 5] * 300,\r\n        "C": [-6.0, -7, -8, -9, 10] * 300,\r\n        "D": [True, False, True, False, False] * 300,\r\n    },\r\n    index=range(10, 15001, 10),\r\n)\r\npdf.var(axis=1)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\n`DataFrame.var()` with `axis=1` returns `float64` Series in Pandas 1.5.3, but now it returns `object` Series instead. So I wonder if it is an intended behavior or an unexpected bug:\r\n\r\n**Pandas 1.5.3**\r\n```python\r\n>>> pdf = pd.DataFrame(\r\n...     {\r\n...         "A": [1, -2, 3, -4, 5] * 300,\r\n...         "B": [1.0, -2, 3, -4, 5] * 300,\r\n...         "C": [-6.0, -7, -8, -9, 10] * 300,\r\n...         "D": [True, False, True, False, False] * 300,\r\n...     },\r\n...     index=range(10, 15001, 10),\r\n... )\r\n>>> pdf.var(axis=1)\r\n10       12.250000\r\n20        8.916667\r\n30       27.583333\r\n40       13.583333\r\n50       16.666667\r\n           ...\r\n14960    12.250000\r\n14970     8.916667\r\n14980    27.583333\r\n14990    13.583333\r\n15000    16.666667\r\nLength: 1500, dtype: float64\r\n```\r\n\r\n**Pandas 2.0.0 and above**\r\n```python\r\n>>> pdf = pd.DataFrame(\r\n...     {\r\n...         "A": [1, -2, 3, -4, 5] * 300,\r\n...         "B": [1.0, -2, 3, -4, 5] * 300,\r\n...         "C": [-6.0, -7, -8, -9, 10] * 300,\r\n...         "D": [True, False, True, False, False] * 300,\r\n...     },\r\n...     index=range(10, 15001, 10),\r\n... )\r\n>>> pdf.var(axis=1)\r\n10           12.25\r\n20        8.916667\r\n30       27.583333\r\n40       13.583333\r\n50       16.666667\r\n           ...\r\n14960        12.25\r\n14970     8.916667\r\n14980    27.583333\r\n14990    13.583333\r\n15000    16.666667\r\nLength: 1500, dtype: object\r\n```\r\n\r\n### Expected Behavior\r\n\r\n```python\r\n>>> pdf = pd.DataFrame(\r\n...     {\r\n...         "A": [1, -2, 3, -4, 5] * 300,\r\n...         "B": [1.0, -2, 3, -4, 5] * 300,\r\n...         "C": [-6.0, -7, -8, -9, 10] * 300,\r\n...         "D": [True, False, True, False, False] * 300,\r\n...     },\r\n...     index=range(10, 15001, 10),\r\n... )\r\n>>> pdf.var(axis=1)\r\n10       12.250000\r\n20        8.916667\r\n30       27.583333\r\n40       13.583333\r\n50       16.666667\r\n           ...\r\n14960    12.250000\r\n14970     8.916667\r\n14980    27.583333\r\n14990    13.583333\r\n15000    16.666667\r\nLength: 1500, dtype: float64\r\n```\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit              : ba1cccd19da778f0c3a7d6a885685da16a072870\r\npython              : 3.9.17.final.0\r\npython-bits         : 64\r\nOS                  : Darwin\r\nOS-release          : 22.6.0\r\nVersion             : Darwin Kernel Version 22.6.0: Wed Jul  5 22:21:53 PDT 2023; root:xnu-8796.141.3~6/RELEASE_ARM64_T6020\r\nmachine             : arm64\r\nprocessor           : arm\r\nbyteorder           : little\r\nLC_ALL              : None\r\nLANG                : None\r\nLOCALE              : None.UTF-8\r\n\r\npandas              : 2.1.0\r\nnumpy               : 1.26.0\r\npytz                : 2023.3\r\ndateutil            : 2.8.2\r\nsetuptools          : 68.0.0\r\npip                 : 23.2.1\r\nCython              : None\r\npytest              : 7.4.0\r\nhypothesis          : None\r\nsphinx              : 3.0.4\r\nblosc               : None\r\nfeather             : None\r\nxlsxwriter          : None\r\nlxml.etre ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55194/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/55187',
#   'id': 1901561244,
#   'node_id': 'I_kwDOAA0YD85xV4Wc',
#   'number': 55187,
#   'title': 'DOC: ',
#   'user': {'login': 'alexandermorgan',
#    'id': 2601689,
#    'node_id': 'MDQ6VXNlcjI2MDE2ODk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2601689?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexandermorgan',
#    'html_url': 'https://github.com/alexandermorgan',
#    'followers_url': 'https://api.github.com/users/alexandermorgan/followers',
#    'following_url': 'https://api.github.com/users/alexandermorgan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alexandermorgan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alexandermorgan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alexandermorgan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alexandermorgan/orgs',
#    'repos_url': 'https://api.github.com/users/alexandermorgan/repos',
#    'events_url': 'https://api.github.com/users/alexandermorgan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alexandermorgan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'jfadia',
#    'id': 90651438,
#    'node_id': 'MDQ6VXNlcjkwNjUxNDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90651438?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jfadia',
#    'html_url': 'https://github.com/jfadia',
#    'followers_url': 'https://api.github.com/users/jfadia/followers',
#    'following_url': 'https://api.github.com/users/jfadia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jfadia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jfadia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jfadia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jfadia/orgs',
#    'repos_url': 'https://api.github.com/users/jfadia/repos',
#    'events_url': 'https://api.github.com/users/jfadia/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jfadia/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jfadia',
#     'id': 90651438,
#     'node_id': 'MDQ6VXNlcjkwNjUxNDM4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/90651438?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jfadia',
#     'html_url': 'https://github.com/jfadia',
#     'followers_url': 'https://api.github.com/users/jfadia/followers',
#     'following_url': 'https://api.github.com/users/jfadia/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jfadia/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jfadia/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jfadia/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jfadia/orgs',
#     'repos_url': 'https://api.github.com/users/jfadia/repos',
#     'events_url': 'https://api.github.com/users/jfadia/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jfadia/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-09-18T18:58:00Z',
#   'updated_at': '2023-09-22T01:49:33Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\npandas.Series.first_valid_index\r\nhttps://github.com/pandas-dev/pandas/blob/ba1cccd19da778f0c3a7d6a885685da16a072870/pandas/core/generic.py#L12341\n\n### Documentation problem\n\nhttps://github.com/pandas-dev/pandas/blob/ba1cccd19da778f0c3a7d6a885685da16a072870/pandas/core/generic.py#L12341\r\nThe "Notes" passage reads: "If all elements are non-NA/null, returns None. Also returns None for empty Series/DataFrame."\r\nbut the "non-" should not be there.\n\n### Suggested fix for documentation\n\nThe "non-" should be deleted from the "Notes" section, resulting in this:\r\n"If all elements are NA/null, returns None. Also returns None for empty Series/DataFrame."',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55187/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
df2 = pd.DataFrame(data1 , columns=['id','url' , 'repository_url' , 'labels_url','user']) # if you want perticular coulumn

# %%
df2.to_csv('json_res.csv')
