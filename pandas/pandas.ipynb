# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 82E2-7C2E
#
#  Directory of C:\Users\Abhishek Sakhare\pandas numpy
#
# 18-09-2023  19:17    <DIR>          .
# 18-09-2023  19:17    <DIR>          ..
# 18-09-2023  18:20    <DIR>          .ipynb_checkpoints
# 18-09-2023  18:43               215 pandas.csv
# 18-09-2023  19:17            26,077 pandas.ipynb
# 18-09-2023  18:25             9,368 pandas.xlsx
# 18-09-2023  19:14             1,098 SampleCSVFile_2kb.csv
#                4 File(s)         36,758 bytes
#                3 Dir(s)  43,797,528,576 bytes free

# %%
pd.read_csv("pandas.csv")
# in first row colunme name is empty
# Out:
#        name             emailid    address  Unnamed: 3    surname
# 0  abhishek  abhishek@gmail.com        ich      416115    sakhare
# 1   prashik   prashik@gmail.com  kolhapure       23456     gavali
# 2    suraj          suraj@gmail       pune       34565  pantankar
# 3   prajwar   prajwal@gmail.com   banglore       34545         ag

# %%
#pd.read_csv("file_locatioin\filename.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("pandas.csv", header=None)
# default colunmn name
# Out:
#           0                   1          2         3          4
# 0      name             emailid    address       NaN    surname
# 1  abhishek  abhishek@gmail.com        ich  416115.0    sakhare
# 2   prashik   prashik@gmail.com  kolhapure   23456.0     gavali
# 3    suraj          suraj@gmail       pune   34565.0  pantankar
# 4   prajwar   prajwal@gmail.com   banglore   34545.0         ag

# %%
#give your own column name
pd.read_csv('pandas.csv', names=['a','b','c','d','e'])
# Out:
#           a                   b          c         d          e
# 0      name             emailid    address       NaN    surname
# 1  abhishek  abhishek@gmail.com        ich  416115.0    sakhare
# 2   prashik   prashik@gmail.com  kolhapure   23456.0     gavali
# 3    suraj          suraj@gmail       pune   34565.0  pantankar
# 4   prajwar   prajwal@gmail.com   banglore   34545.0         ag

# %%
pd.read_csv('pandas.csv', names=['a','b','c','d','e','ww'])
# Out:
#           a                   b          c         d          e  ww
# 0      name             emailid    address       NaN    surname NaN
# 1  abhishek  abhishek@gmail.com        ich  416115.0    sakhare NaN
# 2   prashik   prashik@gmail.com  kolhapure   23456.0     gavali NaN
# 3    suraj          suraj@gmail       pune   34565.0  pantankar NaN
# 4   prajwar   prajwal@gmail.com   banglore   34545.0         ag NaN

# %%
pd.read_csv('pandas.csv', names=['a','b'])
# Out:
#                                               a          b
# name     emailid            address         NaN    surname
# abhishek abhishek@gmail.com ich        416115.0    sakhare
# prashik  prashik@gmail.com  kolhapure   23456.0     gavali
# suraj    suraj@gmail        pune        34565.0  pantankar
# prajwar  prajwal@gmail.com  banglore    34545.0         ag

# %%
import pandas as pd

# Try reading the file with 'latin1' encoding
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380      Clay Rozendal
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
pd.read_csv('SampleCSVFile_2kb.csv', encoding='latin1', sep= '@') # we replaced , by @ s o
# Out:
#     1   Eldon Base for stackable storage shelf@ platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D® Ring Binder@ Heavy Gauge Vinyl       Barry French
# 2   4                                               R380      Clay Rozendal
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings@ Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File@ Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving@ Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df = pd.read_csv('SampleCSVFile_2kb.csv', encoding='latin1', sep= '@') # we replaced , by @ s o
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes # to ger columns datatypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.head() # first 5 records from top
# Out:
#    1   Eldon Base for stackable storage shelf@ platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder@ Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37

# %%
df.head(3) # first 5 records from top
# Out:
#    1   Eldon Base for stackable storage shelf@ platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder@ Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58

# %%
df.tail() # first 5 records from bottom
# Out:
#     1   Eldon Base for stackable storage shelf@ platinum Muhammed MacIntyre  \
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings@ Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File@ Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving@ Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
# 5  613   -54.04    7.30   7.72  Nunavut  Binders and Binder Accessories  0.38
# 6  613   127.70   42.76   6.22  Nunavut          Storage & Organization   NaN
# 7  643  -695.26  138.14  35.00  Nunavut          Storage & Organization   NaN
# 8  678  -226.36    4.98   8.33  Nunavut                           Paper  0.38

# %%
df.tail(3) # first 5 records from bottom last 3
# Out:
#     1 Eldon Base for stackable storage shelf@ platinum Muhammed MacIntyre  \
# 6   8          SAFCO Mobile Desk Side File@ Wire Frame       Carl Jackson
# 7   9            SAFCO Commercial Wire Shelving@ Black     Monica Federle
# 8  10                                        Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut  Storage & Organization   0.8
# 6  613   127.70   42.76   6.22  Nunavut  Storage & Organization   NaN
# 7  643  -695.26  138.14  35.00  Nunavut  Storage & Organization   NaN
# 8  678  -226.36    4.98   8.33  Nunavut                   Paper  0.38

# %%
df.columns # to get columns
# Out:
# Index(['1', 'Eldon Base for stackable storage shelf@ platinum',
#        'Muhammed MacIntyre', '3', '-213.25', '38.94', '35', 'Nunavut',
#        'Storage & Organization', '0.8'],
#       dtype='object')

# %%
df # select * from table
df = pd.read_csv('pandas.csv')
pd.read_csv('pandas.csv')
# Out:
#        name             emailid    address  Unnamed: 3    surname
# 0  abhishek  abhishek@gmail.com        ich      416115    sakhare
# 1   prashik   prashik@gmail.com  kolhapure       23456     gavali
# 2    suraj          suraj@gmail       pune       34565  pantankar
# 3   prajwar   prajwal@gmail.com   banglore       34545         ag

# %%
df['name']
# Out:
# 0    abhishek
# 1     prashik
# 2      suraj
# 3     prajwar
# Name: name, dtype: object

# %%
a =df['name']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df['name','address'] # it gives error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'address')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['name','address']]
# Out:
#        name    address
# 0  abhishek        ich
# 1   prashik  kolhapure
# 2    suraj        pune
# 3   prajwar   banglore

# %%
df[['name','address','surname']]
# Out:
#        name    address    surname
# 0  abhishek        ich    sakhare
# 1   prashik  kolhapure     gavali
# 2    suraj        pune  pantankar
# 3   prajwar   banglore         ag

# %%
df1 = df[['name','address','surname']]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame
